# %%
not True
# Out:
# False

# %%
False == False
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True and False or True and not False # or prior
# Out:
# True

# %%
0.0 and False
# Out:
# 0.0

# %%
0.0 or False
# Out:
# False

# %%
not 0.0
# Out:
# True
